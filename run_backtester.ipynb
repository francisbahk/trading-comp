# %%
from datetime import datetime
from newbacktester import Backtester
# from example_strategy import Strategy
from starter_code import Strategy
import pandas as pd

start = datetime(2024, 1, 1)
end = datetime(2024, 3, 30)
s = Strategy()

b = Backtester(start, end, s)
# Out:
# 2024-03-28 00:00:00
# /Users/francisbahk/Cornell OneDrive/Senior year/trading comp/CTC2024_Ian_Josh_Francis/starter_code.py:234: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma + diff / vega  # f(x) / f'(x)
# /Users/francisbahk/Cornell OneDrive/Senior year/trading comp/CTC2024_Ian_Josh_Francis/starter_code.py:192: RuntimeWarning: invalid value encountered in double_scalars
#   d_1 = (np.log(S / K) + (r + sigma**2 / 2) * t) / (sigma * np.sqrt(t))
# /Users/francisbahk/Cornell OneDrive/Senior year/trading comp/CTC2024_Ian_Josh_Francis/starter_code.py:217: RuntimeWarning: invalid value encountered in double_scalars
#   d_1 = (np.log(S / K) + (r + sigma**2 / 2) * t) / (sigma * np.sqrt(t))
# trading on, vol is: 0.12478516996342519
# capital is: 1000000
# AVERAGE +EV: 0.0
# ORDER NUMBER: 100
# # ORDERS TAKEN: 0
# # of orders: 1 # parsed: 33 #total: 144 ratio of orders that we take:  0.006944444444444444 capital: 996806.4256
# ...

# %%
b.calculate_pnl()
# Out:
# 2024-01-02 00:00:00 capital: 100000000 portfolio value: 0 total pnl: 100000000 open orders: 0
# 2024-01-03 00:00:00 capital: 112867648.0 portfolio value: 2663730.0 total pnl: 115531378.0 open orders: 10
# 2024-01-04 00:00:00 capital: 112556418.0 portfolio value: 2151490.0 total pnl: 114707908.0 open orders: 10
# 2024-01-05 00:00:00 capital: 114434198.0 portfolio value: 1341800.0 total pnl: 115775998.0 open orders: 11
# 2024-01-06 00:00:00 capital: 115738158.0 portfolio value: 427400.0 total pnl: 116165558.0 open orders: 11
# 2024-01-07 00:00:00 capital: 115738158.0 portfolio value: 427400.0 total pnl: 116165558.0 open orders: 11
# 2024-01-08 00:00:00 capital: 115738158.0 portfolio value: 427400.0 total pnl: 116165558.0 open orders: 11
# 2024-01-09 00:00:00 capital: 114903327.0 portfolio value: 2852500.0 total pnl: 117755827.0 open orders: 12
# 2024-01-10 00:00:00 capital: 117922967.0 portfolio value: 1397899.9999999995 total pnl: 119320867.0 open orders: 12
# ...

# %%
b.plot_pnl()

# %%
b.compute_overall_score()
# Out:
# Max Drawdown: 0.007127674007316004
# Overall Return: 424.4354455%
# Sharpe Ratio: 20.53352396553669
# Overall Score: 1222720.8179066638

# %%
# row = s.options.sample(n=1).iloc[0]
# print(row)

# %%
# date_time = row["ts_recv"]
# first = date_time.split(".")[0] + "Z"
# print(first)
# accurate_date = datetime.strptime(first, "%Y-%m-%dT%H:%M:%SZ")
# accurate_date

# %%
# date = s.get_current_date_accurate(row)
# print("date: " + str(date))
# s.get_underlying_price_close(date)

# %%
# s.get_spot_price(row)

# %%
# orders = s.generate_orders()

# %%
# b.orders
